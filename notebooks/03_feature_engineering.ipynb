# %% [markdown]
# # Credit Card Fraud Detection – Feature Engineering

# %% [raw]
# #Purpose of This Notebook
#
# This notebook focuses on creating meaningful, model-ready features from preprocessed transaction data to improve fraud detection performance while maintaining deployment consistency and low inference latency.

# %% [markdown]
# # 1. Import Required Libraries¶

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %% [raw]
# #Purpose : Load libraries required for feature transformation and scaling.
#
# #Why important : Feature engineering must be reproducible and compatible with model training and deployment.
#
# #Achieved : Environment prepared for feature creation and transformation.

# %% [markdown]
# # 2. Load Preprocessed Data

# %%
X_train = pd.read_csv('../data/preprocessed/X_train.csv')
X_test = pd.read_csv('../data/preprocessed/X_test.csv')
y_train = pd.read_csv('../data/preprocessed/y_train.csv')
y_test = pd.read_csv('../data/preprocessed/y_test.csv')

print(X_train.shape, X_test.shape)
# Out:
# (226980, 30) (56746, 30)

# %% [raw]
# #Purpose : Load already cleaned and scaled datasets created in preprocessing step.
#
# #Why important : Ensures no data leakage and clean separation between preprocessing and feature engineering.
#
# #Achieved : Preprocessed train and test datasets successfully loaded.

# %% [markdown]
# # 3. Review Current Features

# %%
X_train.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  2.238954 -1.724499 -2.151484 -2.577803  0.993668  3.565492 -1.785957
# 1 -1.315062  1.630783  0.597001 -0.038359 -0.404580 -0.965712  0.212249
# 2  1.908801  0.021184 -2.087997  0.129310  1.161468  0.605244 -0.022371
# 3  1.811257  0.316556  0.316751  3.880231  0.048454  1.020163 -0.734868
# 4  1.358817 -1.120881  0.550266 -1.547659 -1.194950  0.275448 -1.201843
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.860122 -1.264003  1.567867  ... -0.149574 -0.049333  0.278442  0.684735
# 1  0.735381 -1.267926 -0.482635  ... -0.238898 -0.946773  0.323904  0.515632
# 2  0.180296  0.283819 -0.497766  ...  0.293609  1.095842 -0.044874 -1.689517
# 3  0.233651  0.681423  1.146705  ...  0.138869  0.700422  0.174064  0.702997
# 4  0.212889 -2.094285  1.492821  ... -0.340972 -0.636442  0.252758 -0.344160
#
#         V25       V26       V27       V28  Amount_scaled  Hour
# ...

# %% [raw]
# #Purpose : Understand existing features before engineering new ones.
#
# #Why important : Prevents redundant or conflicting feature creation.
#
# #Achieved : Clear visibility of available numeric and PCA-based features.

# %% [markdown]
# # 4. Interaction Features (High-Risk Feature Interactions)

# %%
X_train['V14_V17_interaction'] = X_train['V14'] * X_train['V17']
X_test['V14_V17_interaction'] = X_test['V14'] * X_test['V17']

# %%
X_train['V14_V17_interaction']
# Out:
# 0        -0.119590
# 1        -0.228902
# 2        -0.546972
# 3        -0.589048
# 4        -0.035154
#             ...
# 226975   -0.022001
# 226976    0.004638
# 226977    0.136498
# 226978    0.022490
# 226979   -0.124266
# Name: V14_V17_interaction, Length: 226980, dtype: float64

# %%
X_test['V14_V17_interaction']
# Out:
# 0       -0.010055
# 1       -0.317451
# 2        1.155403
# 3       -0.117355
# 4       -1.464542
#            ...
# 56741   -0.187663
# 56742   -0.546461
# 56743    0.043213
# 56744   -0.042556
# 56745    0.323842
# Name: V14_V17_interaction, Length: 56746, dtype: float64

# %% [raw]
# #Purpose : Capture non-linear relationships between fraud-sensitive features.
#
# #Why important : Fraud patterns are rarely linear; interaction terms often boost tree-based models.
#
# #Achieved : New interaction feature capturing complex fraud behavior.

# %% [markdown]
# # 5. Transaction Amount Risk Bucketing

# %%
def amount_risk_bucket(amount):
    if amount < 10:
        return 0
    elif amount < 100:
        return 1
    elif amount < 500:
        return 2
    else:
        return 3

X_train['Amount_risk_bucket'] = X_train['Amount_scaled'].apply(amount_risk_bucket)
X_test['Amount_risk_bucket'] = X_test['Amount_scaled'].apply(amount_risk_bucket)

# %%
X_train['Amount_risk_bucket']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 226975    0
# 226976    0
# 226977    0
# 226978    0
# 226979    0
# Name: Amount_risk_bucket, Length: 226980, dtype: int64

# %%
X_test['Amount_risk_bucket']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 56741    0
# 56742    0
# 56743    0
# 56744    0
# 56745    0
# Name: Amount_risk_bucket, Length: 56746, dtype: int64

# %% [raw]
# #Purpose:Convert continuous monetary values into risk-based categorical bins.
#
# #Why important:Fraud often clusters around specific transaction ranges.
#
# #Achieved:Discrete risk-aware representation of transaction amounts.

# %% [markdown]
# # 6. Log Transformation for Stability

# %%
X_train['Amount_log'] = np.log1p(X_train['Amount_scaled'])
X_test['Amount_log'] = np.log1p(X_test['Amount_scaled'])

# %%
X_train['Amount_log']
# Out:
# 0         0.128809
# 1        -0.234607
# 2        -0.104037
# 3        -0.068538
# 4         0.026260
#             ...
# 226975    0.880629
# 226976    1.463733
# 226977    0.187941
# 226978   -0.270099
# 226979   -0.145481
# Name: Amount_log, Length: 226980, dtype: float64

# %%
X_test['Amount_log']
# Out:
# 0       -0.158549
# 1       -0.327258
# 2        0.672424
# 3        1.349023
# 4       -0.337498
#            ...
# 56741   -0.326105
# 56742   -0.183375
# 56743   -0.197627
# 56744   -0.347649
# 56745   -0.088777
# Name: Amount_log, Length: 56746, dtype: float64

# %% [raw]
# #Purpose : Reduce skewness and stabilize variance in monetary features.
#
# #Why important : Improves model convergence and robustness.
#
# #Achieved : Numerically stable, less skewed amount feature.

# %% [markdown]
# # 7. Statistical Aggregation Features (Row-Wise)

# %%
pca_cols = [col for col in X_train.columns if col.startswith('V')]

X_train['pca_mean'] = X_train[pca_cols].mean(axis=1)
X_train['pca_std'] = X_train[pca_cols].std(axis=1)

X_test['pca_mean'] = X_test[pca_cols].mean(axis=1)
X_test['pca_std'] = X_test[pca_cols].std(axis=1)

# %% [raw]
# #Purpose : Summarize PCA feature behavior into compact statistics.
#
# #Why important : Captures overall transaction anomaly strength.
#
# #Achieved : High-level statistical features representing fraud intensity.

# %% [markdown]
# # 8. Feature Scaling (Newly Created Features)

# %%
scaler = StandardScaler()

new_features = [
    'V14_V17_interaction',
    'Amount_log',
    'pca_mean',
    'pca_std'
]

X_train[new_features] = scaler.fit_transform(X_train[new_features])
X_test[new_features] = scaler.transform(X_test[new_features])

# %% [raw]
# #Purpose : Ensure newly engineered features are on comparable scales.
#
# #Why important : Prevents model bias toward large-magnitude features.
#
# #Achieved : Consistent scaling across all engineered features.

# %% [markdown]
# # 9. Final Feature Validation

# %%
X_train.isnull().sum().sum(), X_test.isnull().sum().sum()
# Out:
# (0, 0)

# %% [raw]
# #Purpose : Verify no missing values were introduced.
#
# #Why important : Prevents training and inference failures.
#
# #Achieved : Feature matrix is clean and model-ready.

# %% [markdown]
# # 10. Save Feature-Engineered Data

# %%
X_train.to_csv('../data/preprocessed/X_train_fe.csv', index=False)
X_test.to_csv('../data/preprocessed/X_test_fe.csv', index=False)

# %% [raw]
# #Purpose : Persist final feature set for modeling and deployment.
#
# #Why important : Ensures reproducibility and clean pipeline separation.
#
# #Achieved : Final feature-engineered datasets saved.

# %% [markdown]
# # What This Feature Engineering Notebook Achieves

# %% [raw]
# Area	                                 Outcome
#
# 1.Fraud Pattern Capture	                 Interaction & statistical features
# 2.Numerical Stability                    Log & scaled features
# 3.Model Readiness	                     Fully numeric, clean feature set
# 4.Deployment Safety	                     Deterministic, lightweight features
# 5.Performance Boost	                     Improved signal for ML models

# %% [raw]
# Feature engineering was used to capture non-linear fraud patterns, stabilize monetary values, and summarize transaction behavior, improving model performance while keeping the pipeline production-ready.

# %% [raw]
# This feature engineering pipeline transforms preprocessed transaction data into expressive, stable, and deployment-ready features that capture non-linear fraud behavior and improve model performance.
